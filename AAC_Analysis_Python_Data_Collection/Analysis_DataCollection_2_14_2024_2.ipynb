# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
import pandas as pd

# Read the text file
                   
df = pd.read_csv('../AAB_DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024_2.txt')  # replace '\t' with your delimiter

# Save the DataFrame as a CSV file
df.to_csv('../AAB_DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024_2.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode                            Data
# 0  11:01:36.587   RX  Differential Pressure values:
# 1  11:01:36.587   RX                          -0.21
# 2  11:01:36.587   RX               Pressure values:
# 3  11:01:36.588   RX                       10018.00
# 4  11:01:36.733   RX  Differential Pressure values:

# %%
df.columns
# Out:
# Index(['Timestamp', 'Mode', 'Data'], dtype='object')

# %%
import numpy as np

df['differential pressure value'] = np.where(df['Data'].str.strip() == 'Differential Pressure values:', df['Data'].shift(-1), np.nan)
df['pressure values'] = np.where(df['Data'].str.strip() == 'Pressure values:', df['Data'].shift(-1), np.nan)

# Fill NaN values
df['differential pressure value'].fillna(method='ffill', inplace=True)
df['pressure values'].fillna(method='ffill', inplace=True)

df.head(100)
# Out:
#        Timestamp Mode                            Data  \
# 0   11:01:36.587   RX  Differential Pressure values:
# 1   11:01:36.587   RX                          -0.21
# 2   11:01:36.587   RX               Pressure values:
# 3   11:01:36.588   RX                       10018.00
# 4   11:01:36.733   RX  Differential Pressure values:
# ..           ...  ...                             ...
# 95  11:01:40.006   RX                       10001.40
# 96  11:01:40.155   RX  Differential Pressure values:
# 97  11:01:40.155   RX                         -15.51
# 98  11:01:40.155   RX               Pressure values:
# 99  11:01:40.157   RX                       10002.70
#
#    differential pressure value pressure values
# 0                       -0.21              NaN
# 1                       -0.21              NaN
# 2                       -0.21        10018.00
# 3                       -0.21        10018.00
# 4                       -0.31        10018.00
# ..                         ...             ...
# 95                     -16.81        10001.40
# 96                     -15.51        10001.40
# 97                     -15.51        10001.40
# 98                     -15.51        10002.70
# 99                     -15.51        10002.70
#
# [100 rows x 5 columns]

# %%
df.head(100)  # prints the first 5 rows of the DataFrame
# Out:
#        Timestamp Mode                            Data  \
# 0   11:01:36.587   RX  Differential Pressure values:
# 1   11:01:36.587   RX                          -0.21
# 2   11:01:36.587   RX               Pressure values:
# 3   11:01:36.588   RX                       10018.00
# 4   11:01:36.733   RX  Differential Pressure values:
# ..           ...  ...                             ...
# 95  11:01:40.006   RX                       10001.40
# 96  11:01:40.155   RX  Differential Pressure values:
# 97  11:01:40.155   RX                         -15.51
# 98  11:01:40.155   RX               Pressure values:
# 99  11:01:40.157   RX                       10002.70
#
#    differential pressure value pressure values
# 0                       -0.21              NaN
# 1                       -0.21              NaN
# 2                       -0.21        10018.00
# 3                       -0.21        10018.00
# 4                       -0.31        10018.00
# ..                         ...             ...
# 95                     -16.81        10001.40
# 96                     -15.51        10001.40
# 97                     -15.51        10001.40
# 98                     -15.51        10002.70
# 99                     -15.51        10002.70
#
# [100 rows x 5 columns]

# %%
# Assuming df is your DataFrame

# Find rows where any cell has a NaN value
nan_rows = df[df.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df = df.dropna()
# Out:
#       Timestamp Mode                            Data  \
# 0  11:01:36.587   RX  Differential Pressure values:
# 1  11:01:36.587   RX                          -0.21
#
#   differential pressure value pressure values
# 0                      -0.21              NaN
# 1                      -0.21              NaN

# %%
df.head()
# Out:
#       Timestamp Mode                            Data  \
# 2  11:01:36.587   RX               Pressure values:
# 3  11:01:36.588   RX                       10018.00
# 4  11:01:36.733   RX  Differential Pressure values:
# 5  11:01:36.734   RX                          -0.31
# 6  11:01:36.734   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                      -0.21        10018.00
# 3                      -0.21        10018.00
# 4                      -0.31        10018.00
# 5                      -0.31        10018.00
# 6                      -0.31        10017.90

# %%
df.tail()
# Out:
#          Timestamp Mode                            Data  \
# 5447  11:04:58.669   RX                       10018.50
# 5448  11:04:58.786   RX  Differential Pressure values:
# 5449  11:04:58.817   RX                           0.38
# 5450  11:04:58.818   RX               Pressure values:
# 5451  11:04:58.818   RX                       10018.60
#
#      differential pressure value pressure values
# 5447                       0.28        10018.50
# 5448                       0.38        10018.50
# 5449                       0.38        10018.50
# 5450                       0.38        10018.60
# 5451                       0.38        10018.60

# %%
# Save the DataFrame as a CSV file
df.to_csv('../AAB_DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024_2.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode                            Data
# 0  11:01:36.587   RX  Differential Pressure values:
# 1  11:01:36.587   RX                          -0.21
# 2  11:01:36.587   RX               Pressure values:
# 3  11:01:36.588   RX                       10018.00
# 4  11:01:36.733   RX  Differential Pressure values:

# %%
df.tail()
# Out:
#          Timestamp Mode                            Data
# 5447  11:04:58.669   RX                       10018.50
# 5448  11:04:58.786   RX  Differential Pressure values:
# 5449  11:04:58.817   RX                           0.38
# 5450  11:04:58.818   RX               Pressure values:
# 5451  11:04:58.818   RX                       10018.60

# %%
# Convert 'Timestamp' to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
# Define start and end time
start_time = pd.to_datetime('11:01:36')
end_time = pd.to_datetime('11:04:58')

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time) & (filtered_df['Timestamp'] <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Set the title and labels
plt.title('Data Collection 2_14_2024')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
#plt.ylim(float('-5'), float('90'))

# Add a grid
plt.grid(True)

plt.savefig('Calibration_2_1_2024.png')
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'differential pressure value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11004\3463182896.py in <module>
#       9 filtered_df = filtered_df.copy()
#      10 # Now you can modify 'pressure values' without warnings
# ---> 11 filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')
#      12
#      13
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'differential pressure value'

# %%
# Define start and end time
start_time = pd.to_datetime('11:01:40')
end_time = pd.to_datetime('11:02:40')

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time) & (filtered_df['Timestamp'] <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Set the title and labels
plt.title('Normal Breathing Mouth Closed')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
#plt.ylim(float('-5'), float('90'))

# Add a grid
plt.grid(True)

plt.savefig('Calibration_2_1_2024.png')
# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Assuming 'filtered_df' is your DataFrame
differential_pressure_array = np.array(filtered_df['differential pressure value'])
sample_rate = 12  

def find_positive_peaks(signal):
    
    signal = signal - np.mean(signal) # Removing the mean value of the signal 
    peaks = []
    positive_part = []
    
    for i, value in enumerate(signal):
        if value > 0:
            positive_part.append(value)
        elif positive_part:
            
            peak_index = positive_part.index(max(positive_part))
            peaks.append(peak_index + i - len(positive_part))
            positive_part = []  # Reset positive_part for the next positive part
    
    # Check for any remaining positive part at the end of the signal
    if positive_part:
        peak_index = positive_part.index(max(positive_part))
        peaks.append(peak_index + i - len(positive_part) + 1)
    
    return peaks

# Plot the original signal
time = np.arange(0, len(differential_pressure_array)) / sample_rate
plt.plot(time, differential_pressure_array, label='Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal Plot')
plt.legend()
plt.show()

# Find and plot the peaks
peaks = find_positive_peaks(differential_pressure_array)


plt.plot(time, differential_pressure_array, label='Original Signal')
plt.plot(time[peaks], differential_pressure_array[peaks], 'r.', label='Peaks')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal with Peaks')
plt.legend()
plt.show()

# Display the indices of the peaks
print("Indices of Peaks:", peaks)
# Out:
# Indices of Peaks: [32, 216, 372, 500, 600, 724, 868, 1012, 1140, 1268, 1376, 1484, 1588]

# %%
segments[1]
signal0:88]
# Out:
# array([-16.22111386, -16.22111386, -16.22111386, -16.22111386,
#        -14.92111386, -14.92111386, -14.92111386, -14.92111386,
#        -14.92111386, -14.92111386, -14.92111386, -14.92111386,
#        -11.02111386, -11.02111386, -11.02111386, -11.02111386,
#         -3.92111386,  -3.92111386,  -3.92111386,  -3.92111386,
#         -3.62111386,  -3.62111386,  -3.62111386,  -3.62111386,
#         -3.82111386,  -3.82111386,  -3.82111386,  -3.82111386,
#          4.56888614,   4.56888614,   4.56888614,   4.56888614,
#         11.46888614,  11.46888614,  11.46888614,  11.46888614,
#          9.56888614,   9.56888614,   9.56888614,   9.56888614,
#          8.96888614,   8.96888614,   8.96888614,   8.96888614,
#          7.66888614,   7.66888614,   7.66888614,   7.66888614,
#          6.26888614,   6.26888614,   6.26888614,   6.26888614,
#          6.86888614,   6.86888614,   6.86888614,   6.86888614,
#          6.46888614,   6.46888614,   6.46888614,   6.46888614,
#          8.06888614,   8.06888614,   8.06888614,   8.06888614,
#          6.16888614,   6.16888614,   6.16888614,   6.16888614,
#          5.56888614,   5.56888614,   5.56888614,   5.56888614,
#          5.26888614,   5.26888614,   5.26888614,   5.26888614,
#          4.76888614,   4.76888614,   4.76888614,   4.76888614,
#          4.16888614,   4.16888614,   4.16888614,   4.16888614,
#          3.46888614,   3.46888614,   3.46888614,   3.46888614])

# %%
# Assuming 'filtered_df' is your DataFrame
differential_pressure_array = np.array(filtered_df['differential pressure value'])
sample_rate = 12  

signal = differential_pressure_array - np.mean(differential_pressure_array) 


sign = [0]*len(signal)
signal = np.array(signal)
segments=[]
count = 0
valley_index=[];
# Iterate through the signal
for i, value in enumerate(signal):
    if value < 0:
        if i == len(signal) - 1:
            count += 1
            segments.append(count)
            valley_end, _ = find_peaks(-signal[i-count+1:i+1],distance=count)
            valley_index.extend(valley_end+(i-count+1))
            count = 0

        sign[i] = -1
        count += 1  
    else: 
        #Positive or 0 
        if i != 0 and sign[i - 1] == -1:   
            #Positive but the previous was negative 
            segments.append(count)
            valley, _ = find_peaks(-signal[i-count:i],distance=count)
            valley_index.extend(valley+(i-count))
            count=0
            
        sign[i] = +1    
print(segments)
print(valley_index)


# Plot the original signal
time = np.arange(0, len(signal)) 
plt.plot(time, signal, label='Original Signal')
#plt.plot(time, signal, label='Zero Based Signal
plt.plot(time[valley_index], signal[valley_index], 'r.', label='Peaks')
plt.plot(time,sign, label='Sign')
#draw the valley as x  on the plot 
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal Plot')
plt.grid()
plt.legend()
plt.show()
# Out:
# [28, 68, 60, 36, 40, 52, 72, 56, 52, 52, 40, 32, 56]
# [149, 303, 449, 549, 689, 837, 957, 1085, 1221, 1329, 1447, 1561]

# %%
segments
# Out:
# [28, 68, 60, 36, 40, 52, 72, 56, 52, 52, 40, 32, 56]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'signal_array' is the array of values sampled at 12 Hz
# Create a time array corresponding to the signal
sample_rate = 12  # Replace with your actual sample rate
time = np.arange(0, len(differential_pressure_array)) / sample_rate

# Perform FFT on the signal
fft_result = np.fft.fft(differential_pressure_array)
frequencies = np.fft.fftfreq(len(fft_result), d=1/sample_rate)

# Plot the magnitude spectrum
plt.plot(frequencies, np.abs(fft_result))
plt.title('Fourier Transform of Signal')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.show()

# %%
 peaks, _ = find_peaks(differential_pressure_array)

# %%
# Define start and end time
start_time = pd.to_datetime('11:02:41')
end_time = pd.to_datetime('11:03:41')

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time) & (filtered_df['Timestamp'] <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Set the title and labels
plt.title('Normal Breathing Mouth Open')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
#plt.ylim(float('-5'), float('90'))

# Add a grid
plt.grid(True)

plt.savefig('Calibration_2_1_2024.png')
# Show the plot
plt.show()

# %%
# Assuming 'filtered_df' is your DataFrame
differential_pressure_array = np.array(filtered_df['differential pressure value'])
sample_rate = 12  

signal = differential_pressure_array - np.mean(differential_pressure_array) 


sign = [0]*len(signal)
signal = np.array(signal)
segments=[]
count = 0
valley_index=[];
# Iterate through the signal
for i, value in enumerate(signal):
    if value < 0 or value ==0:
        if i == len(signal) - 10:
            count += 1
            segments.append(count)
            valley_end, _ = find_peaks(-signal[i-count+1:i+1],distance=count)
            valley_index.extend(valley_end+(i-count+1))
            if not valley_end.size>0:
                valley_end = np.argmin([signal[i-count+1], signal[i+1]])
                valley_index.append(valley_end+(i-count+1))
                
            count = 0

        sign[i] = -10
        count += 1  
    else: 
        #Positive or 0 
        if i != 0 and sign[i - 1] == -10:   
            #Positive but the previous was negative 
            segments.append(count)
            valley, _ = find_peaks(-signal[i-count:i],distance=count)
            valley_index.extend(valley+(i-count))
            if not valley.size>0:
                valley =np.argmin([signal[i-count], signal[i]])
                valley_index.append(valley+(i-count))
            
            count=0
            
        sign[i] = +10    
print(segments)
print(valley_index)


# Plot the original signal
time = np.arange(0, len(signal)) 
plt.plot(time, signal, label='Original Signal')

plt.plot(time[valley_index], signal[valley_index], 'r.', label='Peaks')
#plt.plot(time,sign, label='Sign')
#draw the valley as x  on the plot 
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal Plot')
plt.grid()
plt.legend()
plt.show()
# Out:
# [148, 4, 36, 16, 4, 28, 20, 44, 32, 20, 12, 4, 36, 32, 28, 48, 32, 40, 36, 52, 52]
# [9, 196, 209, 317, 340, 417, 496, 573, 673, 749, 768, 812, 845, 901, 993, 1089, 1181, 1285, 1363, 1449, 1565]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Assuming 'filtered_df' is your DataFrame
differential_pressure_array = np.array(filtered_df['differential pressure value'])
sample_rate = 12  

def find_positive_peaks(signal):
    signal = signal - np.mean(signal) 
    peaks = []
    positive_part = []
    
    for i, value in enumerate(signal):
        if value > 0:
            positive_part.append(value)
        elif positive_part:
            # We've reached the end of a positive part
            peak_index = positive_part.index(max(positive_part))
            peaks.append(peak_index + i - len(positive_part))
            positive_part = []  # Reset positive_part for the next positive part
    
    # Check for any remaining positive part at the end of the signal
    if positive_part:
        peak_index = positive_part.index(max(positive_part))
        peaks.append(peak_index + i - len(positive_part) + 1)
    
    return peaks

# Plot the original signal
time = np.arange(0, len(differential_pressure_array)) / sample_rate
plt.plot(time, differential_pressure_array, label='Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal Plot')
plt.legend()
plt.grid()
plt.show()

# Find and plot the peaks
peaks = find_positive_peaks(differential_pressure_array)


plt.plot(time, differential_pressure_array, label='Original Signal')
plt.plot(time[peaks], differential_pressure_array[peaks], 'r.', label='Peaks')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('Differential Pressure Signal with Peaks')
plt.legend()
plt.grid()
plt.show()

# Display the indices of the peaks
print("Indices of Peaks:", peaks)
# Out:
# Indices of Peaks: [156, 200, 260, 332, 368, 456, 524, 620, 708, 764, 792, 820, 868, 936, 1024, 1148, 1216, 1304, 1392, 1500, 1592]
