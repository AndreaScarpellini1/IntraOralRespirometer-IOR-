# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Read the text file
df = pd.read_csv('./DataCollection/DataCollection_1_22_2024/DataCollection1222024.txt')  # replace '\t' with your delimiter

# Save the DataFrame as a CSV file
df.to_csv('./DataCollection/DataCollection_1_22_2024/DataCollection1222024.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_55092\2097063156.py in <module>
#       2
#       3 # Read the text file
# ----> 4 df = pd.read_csv('./DataCollection/DataCollection_1_22_2024/DataCollection1222024.txt')  # replace '\t' with your delimiter
#       5
#       6 # Save the DataFrame as a CSV file
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './DataCollection/DataCollection_1_22_2024/DataCollection1222024.txt'

# %%
# Now try selecting the 'Data' column
df = df.loc[df['Data'] != 'Pressure values:']
# Create a new column 'Sample' with values from 1 to the number of rows
df['Sample'] = range(1, len(df) + 1)

# Save the DataFrame as a CSV file
df.to_csv('./DataCollection_1_22_2024/DataCollection1222024.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode   Data  Sample
# 1  15:16:03.427   RX  -0.09       1
# 3  15:16:03.548   RX  -0.19       2
# 5  15:16:03.667   RX  -0.09       3
# 7  15:16:03.787   RX  -0.19       4
# 9  15:16:03.907   RX   0.00       5

# %%
df.tail()
# Out:
#           Timestamp Mode   Data  Sample
# 50481  16:06:32.814   RX  -1.39   25241
# 50483  16:06:32.917   RX  -1.50   25242
# 50485  16:06:33.037   RX  -1.50   25243
# 50487  16:06:33.159   RX  -1.50   25244
# 50489  16:06:33.277   RX  -1.50   25245

# %%
# Convert 'Timestamp' to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('15:59:30').time()
end_time = pd.to_datetime('16:00:00').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Walking')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-10'), float('10'))

# Add a grid
plt.grid(True)
plt.savefig('Walking_1_22_2024.png')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('16:02:00').time()
end_time = pd.to_datetime('16:02:30').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Nose Respiration')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-10'), float('10'))

# Add a grid
plt.grid(True)
plt.savefig('Nose_1_22_2024.png')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('16:00:10').time()
end_time = pd.to_datetime('16:00:30').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Running')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-22'), float('20'))

# Add a grid
plt.grid(True)

plt.savefig('Running_1_22_2024.png')

# Show the plot
plt.show()
