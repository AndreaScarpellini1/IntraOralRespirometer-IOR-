# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
import pandas as pd

# Read the text file
                   
df = pd.read_csv('../DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024_2.txt')  # replace '\t' with your delimiter

# Save the DataFrame as a CSV file
df.to_csv('../DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024_2.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode                           Data
# 0  11:01:36.587   RX  Differential Pressure values:
# 1  11:01:36.587   RX                          -0.21
# 2  11:01:36.587   RX               Pressure values:
# 3  11:01:36.588   RX                       10018.00
# 4  11:01:36.733   RX  Differential Pressure values:

# %%
# Assuming df is your DataFrame
df['differential pressure value'] = np.where(df['Data'] == 'Differential Pressure values:', df['Data'].shift(-1), np.nan)
df['pressure values'] = np.where(df['Data'] == 'Pressure values:', df['Data'].shift(-1), np.nan)

# Fill NaN values
df['differential pressure value'].fillna(method='ffill', inplace=True)
df['pressure values'].fillna(method='ffill', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Data'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31100\1839286399.py in <module>
#       1 # Assuming df is your DataFrame
# ----> 2 df['differential pressure value'] = np.where(df['Data'] == 'Differential Pressure values:', df['Data'].shift(-1), np.nan)
#       3 df['pressure values'] = np.where(df['Data'] == 'Pressure values:', df['Data'].shift(-1), np.nan)
#       4
#       5 # Fill NaN values
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\.vscode\Anaconda\envs\AndreasEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Data'

# %%
df.head(100)  # prints the first 5 rows of the DataFrame
# Out:
#        Timestamp Mode                           Data
# 0   11:01:36.587   RX  Differential Pressure values:
# 1   11:01:36.587   RX                          -0.21
# 2   11:01:36.587   RX               Pressure values:
# 3   11:01:36.588   RX                       10018.00
# 4   11:01:36.733   RX  Differential Pressure values:
# ..           ...  ...                             ...
# 95  11:01:40.006   RX                       10001.40
# 96  11:01:40.155   RX  Differential Pressure values:
# 97  11:01:40.155   RX                         -15.51
# 98  11:01:40.155   RX               Pressure values:
# 99  11:01:40.157   RX                       10002.70
#
# [100 rows x 3 columns]

# %%
# Assuming df is your DataFrame

# Find rows where any cell has a NaN value
nan_rows = df[df.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df = df.dropna()
# Out:
#       Timestamp Mode                           Data  \
# 0  18:16:41.366   RX  Differential Pressure values:
# 1  18:16:41.366   RX                          -0.01
#
#   differential pressure value pressure values
# 0                       -0.01             NaN
# 1                       -0.01             NaN

# %%
df.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  18:16:41.369   RX               Pressure values:
# 3  18:16:41.369   RX                        9966.90
# 4  18:16:41.516   RX  Differential Pressure values:
# 5  18:16:41.517   RX                           0.28
# 6  18:16:41.517   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.01         9966.90
# 3                       -0.01         9966.90
# 4                        0.28         9966.90
# 5                        0.28         9966.90
# 6                        0.28         9967.20

# %%
df.tail()
# Out:
#          Timestamp Mode                           Data  \
# 5131  18:19:52.231   RX                        9967.30
# 5132  18:19:52.376   RX  Differential Pressure values:
# 5133  18:19:52.377   RX                           0.38
# 5134  18:19:52.379   RX               Pressure values:
# 5135  18:19:52.380   RX                        9967.30
#
#      differential pressure value pressure values
# 5131                        0.38         9967.30
# 5132                        0.38         9967.30
# 5133                        0.38         9967.30
# 5134                        0.38         9967.30
# 5135                        0.38         9967.30

# %%
df.to_csv('../DataCollection/DataCollection_2_14_2024/DataCollection_2_14_2024.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode                           Data  \
# 2  18:16:41.369   RX               Pressure values:
# 3  18:16:41.369   RX                        9966.90
# 4  18:16:41.516   RX  Differential Pressure values:
# 5  18:16:41.517   RX                           0.28
# 6  18:16:41.517   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.01         9966.90
# 3                       -0.01         9966.90
# 4                        0.28         9966.90
# 5                        0.28         9966.90
# 6                        0.28         9967.20

# %%
df.tail()
# Out:
#          Timestamp Mode                           Data  \
# 5131  18:19:52.231   RX                        9967.30
# 5132  18:19:52.376   RX  Differential Pressure values:
# 5133  18:19:52.377   RX                           0.38
# 5134  18:19:52.379   RX               Pressure values:
# 5135  18:19:52.380   RX                        9967.30
#
#      differential pressure value pressure values
# 5131                        0.38         9967.30
# 5132                        0.38         9967.30
# 5133                        0.38         9967.30
# 5134                        0.38         9967.30
# 5135                        0.38         9967.30

# %%
# Convert 'Timestamp' to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
# Define start and end time
start_time = pd.to_datetime('18:16:41')
end_time = pd.to_datetime('18:19:42')

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time) & (filtered_df['Timestamp'] <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Set the title and labels
plt.title('Data Collection 2_14_2024')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
#plt.ylim(float('-5'), float('90'))

# Add a grid
plt.grid(True)

plt.savefig('Calibration_2_1_2024.png')
# Show the plot
plt.show()
