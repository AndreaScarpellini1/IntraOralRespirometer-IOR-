# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# %%
df1 = pd.read_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024.txt')  # replace '\t' with your delimiter
df2 = pd.read_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_2.txt')  # replace '\t' with your delimiter
df3 = pd.read_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_3.txt')  # replace '\t' with your delimiter
df4 = pd.read_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_4.txt')  # replace '\t' with your delimiter
df5 = pd.read_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_5.txt')  # replace '\t' with your delimiter

# Save the DataFrame as a CSV file
df1.to_csv('../DataCollection/Calibration_2_6_2024/Calibration_2_8_2024.csv', index=False)
df2.to_csv('../DataCollection/Calibration_2_6_2024/Calibration_2_8_2024_2.csv', index=False)
df3.to_csv('../DataCollection/Calibration_2_6_2024/Calibration_2_8_2024_3.csv', index=False)
df4.to_csv('../DataCollection/Calibration_2_6_2024/Calibration_2_8_2024_4.csv', index=False)
df5.to_csv('../DataCollection/Calibration_2_6_2024/Calibration_2_8_2024_5.csv', index=False)

# %%
df1.head()
# Out:
#       Timestamp Mode                           Data
# 0  15:33:16.134   RX  Differential Pressure values:
# 1  15:33:16.134   RX                           0.19
# 2  15:33:16.137   RX               Pressure values:
# 3  15:33:16.137   RX                        9821.40
# 4  15:33:16.283   RX  Differential Pressure values:

# %%
df2.head()
# Out:
#       Timestamp Mode                           Data
# 0  15:55:52.710   RX  Differential Pressure values:
# 1  15:55:52.711   RX                          -0.36
# 2  15:55:52.712   RX               Pressure values:
# 3  15:55:52.712   RX                        9837.20
# 4  15:55:52.862   RX  Differential Pressure values:

# %%
df3.head()
# Out:
#       Timestamp Mode                           Data
# 0  16:17:01.512   RX  Differential Pressure values:
# 1  16:17:01.513   RX                          -0.38
# 2  16:17:01.513   RX               Pressure values:
# 3  16:17:01.513   RX                        9838.20
# 4  16:17:01.661   RX  Differential Pressure values:

# %%
df4.head()
# Out:
#       Timestamp Mode                           Data
# 0  16:42:49.969   RX  Differential Pressure values:
# 1  16:42:49.970   RX                          -0.37
# 2  16:42:49.970   RX               Pressure values:
# 3  16:42:49.970   RX                        9837.00
# 4  16:42:50.118   RX  Differential Pressure values:

# %%
df5.head()
# Out:
#       Timestamp Mode                           Data
# 0  17:04:53.739   RX  Differential Pressure values:
# 1  17:04:53.739   RX                          -0.12
# 2  17:04:53.739   RX               Pressure values:
# 3  17:04:53.739   RX                        9835.40
# 4  17:04:53.886   RX  Differential Pressure values:

# %%
# Assuming df is your DataFrame
df1['differential pressure value'] = np.where(df1['Data'] == 'Differential Pressure values:', df1['Data'].shift(-1), np.nan)
df1['pressure values'] = np.where(df1['Data'] == 'Pressure values:', df1['Data'].shift(-1), np.nan)
df1['differential pressure value'].fillna(method='ffill', inplace=True)
df1['pressure values'].fillna(method='ffill', inplace=True)

df2['differential pressure value'] = np.where(df2['Data'] == 'Differential Pressure values:', df2['Data'].shift(-1), np.nan)
df2['pressure values'] = np.where(df2['Data'] == 'Pressure values:', df2['Data'].shift(-1), np.nan)
df2['differential pressure value'].fillna(method='ffill', inplace=True)
df2['pressure values'].fillna(method='ffill', inplace=True)

df3['differential pressure value'] = np.where(df3['Data'] == 'Differential Pressure values:', df3['Data'].shift(-1), np.nan)
df3['pressure values'] = np.where(df3['Data'] == 'Pressure values:', df3['Data'].shift(-1), np.nan)
df3['differential pressure value'].fillna(method='ffill', inplace=True)
df3['pressure values'].fillna(method='ffill', inplace=True)

df4['differential pressure value'] = np.where(df4['Data'] == 'Differential Pressure values:', df4['Data'].shift(-1), np.nan)
df4['pressure values'] = np.where(df4['Data'] == 'Pressure values:', df4['Data'].shift(-1), np.nan)
df4['differential pressure value'].fillna(method='ffill', inplace=True)
df4['pressure values'].fillna(method='ffill', inplace=True)

df5['differential pressure value'] = np.where(df5['Data'] == 'Differential Pressure values:', df5['Data'].shift(-1), np.nan)
df5['pressure values'] = np.where(df5['Data'] == 'Pressure values:', df5['Data'].shift(-1), np.nan)
df5['differential pressure value'].fillna(method='ffill', inplace=True)
df5['pressure values'].fillna(method='ffill', inplace=True)

# %%
df1.head(100)  # prints the first 5 rows of the DataFrame
# Out:
#        Timestamp Mode                           Data  \
# 0   15:33:16.134   RX  Differential Pressure values:
# 1   15:33:16.134   RX                           0.19
# 2   15:33:16.137   RX               Pressure values:
# 3   15:33:16.137   RX                        9821.40
# 4   15:33:16.283   RX  Differential Pressure values:
# ..           ...  ...                            ...
# 95  15:33:19.585   RX                        9821.70
# 96  15:33:19.733   RX  Differential Pressure values:
# 97  15:33:19.734   RX                          -0.10
# 98  15:33:19.737   RX               Pressure values:
# 99  15:33:19.737   RX                        9821.70
#
#    differential pressure value pressure values
# 0                         0.19             NaN
# 1                         0.19             NaN
# 2                         0.19         9821.40
# 3                         0.19         9821.40
# 4                        -0.30         9821.40
# ...

# %%
df2.head(100)
# Out:
#        Timestamp Mode                           Data  \
# 0   15:55:52.710   RX  Differential Pressure values:
# 1   15:55:52.711   RX                          -0.36
# 2   15:55:52.712   RX               Pressure values:
# 3   15:55:52.712   RX                        9837.20
# 4   15:55:52.862   RX  Differential Pressure values:
# ..           ...  ...                            ...
# 95  15:55:56.190   RX                        9837.20
# 96  15:55:56.310   RX  Differential Pressure values:
# 97  15:55:56.311   RX                          -0.36
# 98  15:55:56.313   RX               Pressure values:
# 99  15:55:56.314   RX                        9837.30
#
#    differential pressure value pressure values
# 0                        -0.36             NaN
# 1                        -0.36             NaN
# 2                        -0.36         9837.20
# 3                        -0.36         9837.20
# 4                        -0.16         9837.20
# ...

# %%
df3.head(100)
# Out:
#        Timestamp Mode                           Data  \
# 0   16:17:01.512   RX  Differential Pressure values:
# 1   16:17:01.513   RX                          -0.38
# 2   16:17:01.513   RX               Pressure values:
# 3   16:17:01.513   RX                        9838.20
# 4   16:17:01.661   RX  Differential Pressure values:
# ..           ...  ...                            ...
# 95  16:17:04.964   RX                        9838.30
# 96  16:17:05.111   RX  Differential Pressure values:
# 97  16:17:05.112   RX                          -0.48
# 98  16:17:05.112   RX               Pressure values:
# 99  16:17:05.112   RX                        9838.10
#
#    differential pressure value pressure values
# 0                        -0.38             NaN
# 1                        -0.38             NaN
# 2                        -0.38         9838.20
# 3                        -0.38         9838.20
# 4                        -0.08         9838.20
# ...

# %%
df4.head(100)
# Out:
#        Timestamp Mode                           Data  \
# 0   16:42:49.969   RX  Differential Pressure values:
# 1   16:42:49.970   RX                          -0.37
# 2   16:42:49.970   RX               Pressure values:
# 3   16:42:49.970   RX                        9837.00
# 4   16:42:50.118   RX  Differential Pressure values:
# ..           ...  ...                            ...
# 95  16:42:53.449   RX                        9837.40
# 96  16:42:53.568   RX  Differential Pressure values:
# 97  16:42:53.570   RX                          -0.17
# 98  16:42:53.570   RX               Pressure values:
# 99  16:42:53.570   RX                        9837.20
#
#    differential pressure value pressure values
# 0                        -0.37             NaN
# 1                        -0.37             NaN
# 2                        -0.37         9837.00
# 3                        -0.37         9837.00
# 4                        -0.27         9837.00
# ...

# %%
df5.head(100)
# Out:
#        Timestamp Mode                           Data  \
# 0   17:04:53.739   RX  Differential Pressure values:
# 1   17:04:53.739   RX                          -0.12
# 2   17:04:53.739   RX               Pressure values:
# 3   17:04:53.739   RX                        9835.40
# 4   17:04:53.886   RX  Differential Pressure values:
# ..           ...  ...                            ...
# 95  17:04:57.217   RX                        9835.60
# 96  17:04:57.336   RX  Differential Pressure values:
# 97  17:04:57.337   RX                          -0.22
# 98  17:04:57.337   RX               Pressure values:
# 99  17:04:57.337   RX                        9835.70
#
#    differential pressure value pressure values
# 0                        -0.12             NaN
# 1                        -0.12             NaN
# 2                        -0.12         9835.40
# 3                        -0.12         9835.40
# 4                        -0.22         9835.40
# ...

# %%
# Find rows where any cell has a NaN value
nan_rows = df1[df1.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df1 = df1.dropna()

nan_rows = df2[df2.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df2 = df2.dropna()

nan_rows = df3[df3.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df3 = df3.dropna()

nan_rows = df4[df4.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df4 = df4.dropna()

nan_rows = df5[df5.isna().any(axis=1)]
print(nan_rows)
# Drop rows where any cell has a NaN value
df5 = df5.dropna()
# Out:
#       Timestamp Mode                           Data  \
# 0  15:33:16.134   RX  Differential Pressure values:
# 1  15:33:16.134   RX                           0.19
#
#   differential pressure value pressure values
# 0                        0.19             NaN
# 1                        0.19             NaN
#       Timestamp Mode                           Data  \
# 0  15:55:52.710   RX  Differential Pressure values:
# 1  15:55:52.711   RX                          -0.36
#
#   differential pressure value pressure values
# 0                       -0.36             NaN
# 1                       -0.36             NaN
#       Timestamp Mode                           Data  \
# 0  16:17:01.512   RX  Differential Pressure values:
# 1  16:17:01.513   RX                          -0.38
#
#   differential pressure value pressure values
# 0                       -0.38             NaN
# 1                       -0.38             NaN
#       Timestamp Mode                           Data  \
# ...

# %%
df1.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  15:33:16.137   RX               Pressure values:
# 3  15:33:16.137   RX                        9821.40
# 4  15:33:16.283   RX  Differential Pressure values:
# 5  15:33:16.284   RX                          -0.30
# 6  15:33:16.284   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                        0.19         9821.40
# 3                        0.19         9821.40
# 4                       -0.30         9821.40
# 5                       -0.30         9821.40
# 6                       -0.30         9822.00

# %%
df1.tail()
# Out:
#           Timestamp Mode                           Data  \
# 28187  15:50:54.210   RX                        9880.80
# 28188  15:50:54.359   RX  Differential Pressure values:
# 28189  15:50:54.364   RX                          58.69
# 28190  15:50:54.364   RX               Pressure values:
# 28191  15:50:54.364   RX                        9880.40
#
#       differential pressure value pressure values
# 28187                       58.69         9880.80
# 28188                       58.69         9880.80
# 28189                       58.69         9880.80
# 28190                       58.69         9880.40
# 28191                       58.69         9880.40

# %%
df2.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  15:55:52.712   RX               Pressure values:
# 3  15:55:52.712   RX                        9837.20
# 4  15:55:52.862   RX  Differential Pressure values:
# 5  15:55:52.862   RX                          -0.16
# 6  15:55:52.862   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.36         9837.20
# 3                       -0.36         9837.20
# 4                       -0.16         9837.20
# 5                       -0.16         9837.20
# 6                       -0.16         9837.60

# %%
df2.tail()
# Out:
#           Timestamp Mode                           Data  \
# 25759  16:11:59.916   RX                        9899.70
# 25760  16:12:00.064   RX  Differential Pressure values:
# 25761  16:12:00.067   RX                          61.83
# 25762  16:12:00.067   RX               Pressure values:
# 25763  16:12:00.067   RX                        9899.50
#
#       differential pressure value pressure values
# 25759                       62.03         9899.70
# 25760                       61.83         9899.70
# 25761                       61.83         9899.70
# 25762                       61.83         9899.50
# 25763                       61.83         9899.50

# %%
df3.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  16:17:01.513   RX               Pressure values:
# 3  16:17:01.513   RX                        9838.20
# 4  16:17:01.661   RX  Differential Pressure values:
# 5  16:17:01.662   RX                          -0.08
# 6  16:17:01.662   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.38         9838.20
# 3                       -0.38         9838.20
# 4                       -0.08         9838.20
# 5                       -0.08         9838.20
# 6                       -0.08         9838.30

# %%
df3.tail()
# Out:
#           Timestamp Mode                           Data  \
# 28311  16:34:44.332   RX                        9895.00
# 28312  16:34:44.479   RX  Differential Pressure values:
# 28313  16:34:44.479   RX                          56.51
# 28314  16:34:44.479   RX               Pressure values:
# 28315  16:34:44.480   RX                        9895.00
#
#       differential pressure value pressure values
# 28311                       56.41         9895.00
# 28312                       56.51         9895.00
# 28313                       56.51         9895.00
# 28314                       56.51         9895.00
# 28315                       56.51         9895.00

# %%
df4.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  16:42:49.970   RX               Pressure values:
# 3  16:42:49.970   RX                        9837.00
# 4  16:42:50.118   RX  Differential Pressure values:
# 5  16:42:50.119   RX                          -0.27
# 6  16:42:50.122   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.37         9837.00
# 3                       -0.37         9837.00
# 4                       -0.27         9837.00
# 5                       -0.27         9837.00
# 6                       -0.27         9837.10

# %%
df4.tail()
# Out:
#           Timestamp Mode                           Data  \
# 26779  16:59:34.952   RX                        9895.80
# 26780  16:59:35.101   RX  Differential Pressure values:
# 26781  16:59:35.108   RX                          58.42
# 26782  16:59:35.109   RX               Pressure values:
# 26783  16:59:35.133   RX                        9895.90
#
#       differential pressure value pressure values
# 26779                       58.42         9895.80
# 26780                       58.42         9895.80
# 26781                       58.42         9895.80
# 26782                       58.42         9895.90
# 26783                       58.42         9895.90

# %%
df5.head()
# Out:
#       Timestamp Mode                           Data  \
# 2  17:04:53.739   RX               Pressure values:
# 3  17:04:53.739   RX                        9835.40
# 4  17:04:53.886   RX  Differential Pressure values:
# 5  17:04:53.887   RX                          -0.22
# 6  17:04:53.889   RX               Pressure values:
#
#   differential pressure value pressure values
# 2                       -0.12         9835.40
# 3                       -0.12         9835.40
# 4                       -0.22         9835.40
# 5                       -0.22         9835.40
# 6                       -0.22         9835.80

# %%
df5.tail()
# Out:
#           Timestamp Mode                           Data  \
# 27631  17:22:10.344   RX                        9893.80
# 27632  17:22:10.493   RX  Differential Pressure values:
# 27633  17:22:10.495   RX                          57.87
# 27634  17:22:10.495   RX               Pressure values:
# 27635  17:22:10.496   RX                        9893.90
#
#       differential pressure value pressure values
# 27631                       57.97         9893.80
# 27632                       57.87         9893.80
# 27633                       57.87         9893.80
# 27634                       57.87         9893.90
# 27635                       57.87         9893.90

# %%
df1.to_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_1.csv', index=False)
df2.to_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_2.csv', index=False)
df3.to_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_3.csv', index=False)
df4.to_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_4.csv', index=False)
df5.to_csv('../DataCollection/Calibration_2_8_2024/Calibration_2_8_2024_5.csv', index=False)

# %%
# Convert 'Timestamp' to datetime
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])
df3['Timestamp'] = pd.to_datetime(df3['Timestamp'])
df4['Timestamp'] = pd.to_datetime(df4['Timestamp'])
df5['Timestamp'] = pd.to_datetime(df5['Timestamp'])

# %%
# Define start and end time
start_time_1 = pd.to_datetime('15:33:16')
end_time_1 = pd.to_datetime('15:50:54')

# Filter rows between start time and end time
filtered_df = df1.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_1) & (filtered_df['Timestamp'] <= end_time_1)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at

times_1 = ["15:33:23", "15:34:23", #1
           "15:34:43", "15:35:43", #0.5
           "15:37:15", "15:38:15", #1
           "15:38:30", "15:39:30", #1.5
           "15:39:40", "15:40:40", #2
           "15:40:59", "15:41:59", #2.5
           "15:42:02", "15:43:02", #3
           "15:43:16", "15:44:16", #3.5
           "15:44:35", "15:45:35", #4
           "15:45:50", "15:46:50", #4.5
           "15:47:11", "15:48:11", #5
           "15:48:35", "15:49:35", #5.5
           "15:49:47", "15:50:47"];#6 


labels = ['0 cm H20',
          '0.5 cm H20',
          '1 cm H20',
          '1.5 cm H20',
          '2 cm H20',
          '2.5 cm H20',
          '3 cm H20',
          '3.5 cm H20',
          '4 cm H20',
          '4.5 cm H20',
          '5 cm H20',
          '5.5 cm H20',
          '6 cm H20']

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_1]

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Plot vertical lines at the specified times
for i, t in enumerate(times):
    plt.axvline(x=t, color='r', linestyle='--')
    if i % 2 == 0:  # for the first, third, fifth, etc. lines
        plt.text(t, 70, labels[min(i//2, len(labels)-1)], rotation=90, va='bottom', ha='right')

# Set the title and labels
plt.title('Calibration Curve (ΔmBar - cmH20)')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-2'), float('90'))

# Add a grid
plt.grid(True)


# Show the plot
plt.show()

# %%
# Define start and end time
start_time_2 = pd.to_datetime('15:52:52')
end_time_2 = pd.to_datetime('16:12:00')

# Filter rows between start time and end time
filtered_df = df2.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_2) & (filtered_df['Timestamp'] <= end_time_2)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at

times_2= ["15:56:11", "15:57:11", #0
          "15:57:41", "15:58:41", #0.5
          "15:58:52", "15:59:52", #1
          "16:00:13", "16:01:13", #1.5
          "16:01:19", "16:02:19", #2
          "16:02:33", "16:03:33", #2.5
          "16:03:40", "16:04:40", #3 
          "16:04:52", "16:05:52", #3.5 
          "16:06:05", "16:07:05", #4 
          "16:07:20", "16:08:20", #4.5 
          "16:08:32", "16:09:32", #5 
          "16:09:42", "16:10:42", #5.5 
          "16:10:55", "16:11:55", #6 
];


labels    = ['0 cm H20',
            '0.5 cm H20',
            '1 cm H20',
            '1.5 cm H20',
            '2 cm H20',
            '2.5 cm H20',
            '3 cm H20',
            '3.5 cm H20',
            '4 cm H20',
            '4.5 cm H20',
            '5 cm H20',
            '5.5 cm H20',
            '6 cm H20']

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_2]

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Plot vertical lines at the specified times
for i, t in enumerate(times):
    plt.axvline(x=t, color='r', linestyle='--')
    if i % 2 == 0:  # for the first, third, fifth, etc. lines
        plt.text(t, 70, labels[min(i//2, len(labels)-1)], rotation=90, va='bottom', ha='right')

# Set the title and labels
plt.title('Calibration Curve (ΔmBar - cmH20)')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-2'), float('90'))

# Add a grid
plt.grid(True)


# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Your existing code...

# Filter rows between start time and end time
filtered_df = df2.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_2) & (filtered_df['Timestamp'] <= end_time_2)]

# Convert 'differential pressure value' to numeric, handling errors
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_2]

# Initialize lists to store mean and std values for each pressure level
mean_values = []
std_values = []

# Loop through each pressure level
for i in range(0, len(times)-1, 2):
    # Filter data for the specific time interval
    pressure_level_data = filtered_df[(filtered_df['Timestamp'] >= times[i]) & (filtered_df['Timestamp'] <= times[i+1])]
    
    # Calculate mean and std for the filtered data
    mean_value = pressure_level_data['differential pressure value'].mean()
    std_value = pressure_level_data['differential pressure value'].std()
    
    # Append mean and std values to the lists
    mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression to fit a line
slope, intercept, r_value, p_value, std_err = linregress(range(len(labels)), mean_values)

# Calculate R-squared
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars
plt.errorbar(labels, mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars')

# Plot the regression line
plt.plot(labels, [intercept + slope * i for i in range(len(labels))], color='r', label=f'Regression Line (R²={r_squared:.4f})')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Line')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
print(f'Slope: {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
print(f'R-squared: {r_squared:.4f}')

plt.show()
# Out:
# Slope: 5.07
# Intercept: 1.65
# R-squared: 0.9985

# %%
# Define start and end time
start_time_3 = pd.to_datetime('16:17:01')
end_time_3 = pd.to_datetime('16:34:44')

# Filter rows between start time and end time
filtered_df = df3.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_3) & (filtered_df['Timestamp'] <= end_time_3)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at

times_3= ["16:17:11", "16:18:11",
          "16:18:38", "16:19:38",
          "16:20:11", "16:21:11",
          "16:21:56", "16:22:56",
          "16:23:14", "16:24:14",
          "16:24:29", "16:25:29",
          "16:25:49", "16:26:49",
          "16:27:07", "16:28:07",
          "16:28:40", "16:29:14",  
          "16:29:41", "16:30:41",
          "16:30:58", "16:31:58",  
          "16:32:09", "16:33:09", 
          "16:33:37", "16:34:37",  
]


labels    = ['0 cm H20',
            '0.5 cm H20',
            '1 cm H20',
            '1.5 cm H20',
            '2 cm H20',
            '2.5 cm H20',
            '3 cm H20',
            '3.5 cm H20',
            '4 cm H20',
            '4.5 cm H20',
            '5 cm H20',
            '5.5 cm H20',
            '6 cm H20']

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_3]

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Plot vertical lines at the specified times
for i, t in enumerate(times):
    plt.axvline(x=t, color='r', linestyle='--')
    if i % 2 == 0:  # for the first, third, fifth, etc. lines
        plt.text(t, 70, labels[min(i//2, len(labels)-1)], rotation=90, va='bottom', ha='right')

# Set the title and labels
plt.title('Calibration Curve (ΔmBar - cmH20)')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-2'), float('90'))

# Add a grid
plt.grid(True)


# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define start and end time for the third set of data
start_time_3 = pd.to_datetime('16:17:01')
end_time_3 = pd.to_datetime('16:34:44')

# Filter rows between start time and end time
filtered_df = df3.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_3) & (filtered_df['Timestamp'] <= end_time_3)]

# Convert 'differential pressure value' to numeric, handling errors
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at for the third set of data
times_3 = ["16:17:11", "16:18:11",
           "16:18:38", "16:19:38",
           "16:20:11", "16:21:11",
           "16:21:56", "16:22:56",
           "16:23:14", "16:24:14",
           "16:24:29", "16:25:29",
           "16:25:49", "16:26:49",
           "16:27:07", "16:28:07",
           "16:28:40", "16:29:14",  
           "16:29:41", "16:30:41",
           "16:30:58", "16:31:58",  
           "16:32:09", "16:33:09", 
           "16:33:37", "16:34:37",  
]

labels = ['0 cm H20', '0.5 cm H20', '1 cm H20', '1.5 cm H20', '2 cm H20', '2.5 cm H20',
          '3 cm H20', '3.5 cm H20', '4 cm H20', '4.5 cm H20', '5 cm H20', '5.5 cm H20', '6 cm H20']

# Convert the times to datetime for the third set of data
times = [pd.to_datetime(t) for t in times_3]

# Initialize lists to store mean and std values for each pressure level
mean_values = []
std_values = []

# Loop through each pressure level for the third set of data
for i in range(0, len(times)-1, 2):
    # Filter data for the specific time interval
    pressure_level_data = filtered_df[(filtered_df['Timestamp'] >= times[i]) & (filtered_df['Timestamp'] <= times[i+1])]
    
    # Calculate mean and std for the filtered data
    mean_value = pressure_level_data['differential pressure value'].mean()
    std_value = pressure_level_data['differential pressure value'].std()
    
    # Append mean and std values to the lists
    mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression to fit a line
slope, intercept, r_value, p_value, std_err = linregress(range(len(labels)), mean_values)

# Calculate R-squared
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars
plt.errorbar(labels, mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars')

# Plot the regression line
plt.plot(labels, [intercept + slope * i for i in range(len(labels))], color='r', label=f'Regression Line (R²={r_squared:.4f})')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Line (Set 3)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
print(f'Slope: {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
print(f'R-squared: {r_squared:.4f}')

plt.show()
# Out:
# Slope: 4.50
# Intercept: 2.10
# R-squared: 0.9961

# %%
# Define start and end time
start_time_4 = pd.to_datetime('16:42:34')
end_time_4 = pd.to_datetime('17:04:53')
#start_time_4 = pd.to_datetime('1:59:34')
#end_time_4 = pd.to_datetime('23:04:53')
# Filter rows between start time and end time
filtered_df = df4.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_4) & (filtered_df['Timestamp'] <= end_time_4)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at

times_4 = [
    "16:42:58", "16:43:58", # 0
    "16:44:15", "16:45:15", # 0.5
    "16:45:17", "16:46:17", # 1
    "16:46:34", "16:46:34", # 1.5
    "16:48:07", "16:49:07", # 2
    "16:49:26", "16:50:26", # 2.5
    "16:50:49", "16:51:49", # 3
    "16:51:59", "16:52:59", # 3.5
    "16:53:15", "16:54:15", # 4
    "16:55:02", "16:56:02", # 4.5
    "16:56:26", "16:57:26", # 5
    "16:57:42", "16:58:42", # 5.5
    "16:58:55", "16:59:55"  # 6
]


labels    = ['0 cm H20',
            '0.5 cm H20',
            '1 cm H20',
            '1.5 cm H20',
            '2 cm H20',
            '2.5 cm H20',
            '3 cm H20',
            '3.5 cm H20',
            '4 cm H20',
            '4.5 cm H20'
            '5 cm H20',
            '5.5 cm H20',
            '6 cm H20']

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_4]

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Plot vertical lines at the specified times
for i, t in enumerate(times):
    plt.axvline(x=t, color='r', linestyle='--')
    if i % 2 == 0:  # for the first, third, fifth, etc. lines
        plt.text(t, 70, labels[min(i//2, len(labels)-1)], rotation=90, va='bottom', ha='right')

# Set the title and labels
plt.title('Calibration Curve (ΔmBar - cmH20)')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-2'), float('90'))

# Add a grid
plt.grid(True)


# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define start and end time for the fourth set of data
start_time_4 = pd.to_datetime('16:42:34')
end_time_4 = pd.to_datetime('17:04:53')

# Filter rows between start time and end time
filtered_df = df4.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_4) & (filtered_df['Timestamp'] <= end_time_4)]

# Convert 'differential pressure value' to numeric, handling errors
filtered_df['differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at for the fourth set of data
times_4 = [
    "16:42:58", "16:43:58",  # 0
    "16:44:15", "16:45:15",  # 0.5
    "16:45:17", "16:46:17",  # 1
    "16:46:34", "16:47:34",  # 1.5
    "16:48:07", "16:49:07",  # 2
    "16:49:26", "16:50:26",  # 2.5
    "16:50:49", "16:51:49",  # 3
    "16:51:59", "16:52:59",  # 3.5
    "16:53:15", "16:54:15",  # 4
    "16:55:02", "16:56:02",  # 4.5
    "16:56:26", "16:57:26",  # 5
    "16:57:42", "16:58:42",  # 5.5
    "16:58:55", "16:59:55"   # 6
]

labels = ['0 cm H20', '0.5 cm H20', '1 cm H20', '1.5 cm H20', '2 cm H20', '2.5 cm H20',
          '3 cm H20', '3.5 cm H20', '4 cm H20', '4.5 cm H20', '5 cm H20', '5.5 cm H20', '6 cm H20']

# Convert the times to datetime for the fourth set of data
times = [pd.to_datetime(t) for t in times_4]

# Initialize lists to store valid mean and std values for each pressure level
valid_mean_values = []
std_values = []

# Loop through each pressure level for the fourth set of data
for i in range(0, len(times)-1, 2):
    # Filter data for the specific time interval
    pressure_level_data = filtered_df[(filtered_df['Timestamp'] >= times[i]) & (filtered_df['Timestamp'] <= times[i+1])]
    
    # Calculate mean and std for the filtered data
    mean_value = pressure_level_data['differential pressure value'].mean()
    
    std_value = pressure_level_data['differential pressure value'].std()
    
    
    # Append mean and std values to the lists
    valid_mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression to fit a line
slope, intercept, r_value, p_value, std_err = linregress(range(len(valid_mean_values)), valid_mean_values)

# Calculate R-squared
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars
plt.errorbar(labels[:len(valid_mean_values)], valid_mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars')

# Plot the regression line
plt.plot(labels, [intercept + slope * i for i in range(len(labels))], color='r', label=f'Regression Line (R²={r_squared:.4f})')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Line (Set 4)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
print(f'Slope: {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
print(f'R-squared: {r_squared:.4f}')

plt.show()
# Out:
# Slope: 4.54
# Intercept: 4.24
# R-squared: 0.9926

# %%
# Define start and end time

start_time_5 = pd.to_datetime('17:04:53')
end_time_5 = pd.to_datetime('17:22:10')

# Filter rows between start time and end time
filtered_df = df5.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_5) & (filtered_df['Timestamp'] <= end_time_5)]

filtered_df = filtered_df.copy()
# Now you can modify 'pressure values' without warnings
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at

times_5 = [
    "17:05:03", "17:06:03", # 0
    "17:06:33", "17:07:33", # 0.5
    "17:08:41", "17:09:41", # 1
    "17:09:53", "17:10:53", # 1.5
    "17:11:13", "17:11:14", # 2
    "17:12:15", "17:13:15", # 2.5
    "17:13:37", "17:14:37", # 3
    "17:14:51", "17:15:51", # 3.5
    "17:16:05", "17:17:05", # 4
    "17:17:16", "17:18:16", # 4.5
    "17:18:33", "17:19:33", # 5
    "17:19:47", "17:20:47", # 5.5
    "17:21:07", "17:22:07"  # 6
]



labels    = ['0 cm H20',
            '0.5 cm H20',
            '1 cm H20',
            '1.5 cm H20',
            '2 cm H20',
            '2.5 cm H20',
            '3 cm H20',
            '3.5 cm H20',
            '4 cm H20',
            '4.5 cm H20'
            '5 cm H20',
            '5.5 cm H20',
            '6 cm H20']

# Convert the times to datetime
times = [pd.to_datetime(t) for t in times_5]

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['differential pressure value'])

# Plot vertical lines at the specified times
for i, t in enumerate(times):
    plt.axvline(x=t, color='r', linestyle='--')
    if i % 2 == 0:  # for the first, third, fifth, etc. lines
        plt.text(t, 70, labels[min(i//2, len(labels)-1)], rotation=90, va='bottom', ha='right')

# Set the title and labels
plt.title('Calibration Curve (ΔmBar - cmH20)')
plt.xlabel('Timestamp')
plt.ylabel('Differential Pressure Readings')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-2'), float('90'))

# Add a grid
plt.grid(True)


# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define start and end time for the fifth set of data
start_time_5 = pd.to_datetime('17:04:53')
end_time_5 = pd.to_datetime('17:22:10')

# Filter rows between start time and end time
filtered_df = df5.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'] >= start_time_5) & (filtered_df['Timestamp'] <= end_time_5)]

# Convert 'differential pressure value' to numeric, handling errors
filtered_df.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at for the fifth set of data
times_5 = [
    "17:05:03", "17:06:03",  # 0
    "17:06:33", "17:07:33",  # 0.5
    "17:08:41", "17:09:41",  # 1
    "17:09:53", "17:10:53",  # 1.5
    "17:11:13", "17:11:14",  # 2
    "17:12:15", "17:13:15",  # 2.5
    "17:13:37", "17:14:37",  # 3
    "17:14:51", "17:15:51",  # 3.5
    "17:16:05", "17:17:05",  # 4
    "17:17:16", "17:18:16",  # 4.5
    "17:18:33", "17:19:33",  # 5
    "17:19:47", "17:20:47",  # 5.5
    "17:21:07", "17:22:07"   # 6
]

labels = ['0 cm H20', '0.5 cm H20', '1 cm H20', '1.5 cm H20', '2 cm H20', '2.5 cm H20',
          '3 cm H20', '3.5 cm H20', '4 cm H20', '4.5 cm H20', '5 cm H20', '5.5 cm H20', '6 cm H20']

# Convert the times to datetime for the fifth set of data
times = [pd.to_datetime(t) for t in times_5]

# Initialize lists to store mean and std values for each pressure level
mean_values = []
std_values = []

# Loop through each pressure level for the fifth set of data
for i in range(0, len(times)-1, 2):
    # Filter data for the specific time interval
    pressure_level_data = filtered_df[(filtered_df['Timestamp'] >= times[i]) & (filtered_df['Timestamp'] <= times[i+1])]
    
    # Calculate mean and std for the filtered data
    mean_value = pressure_level_data['differential pressure value'].mean()
    std_value = pressure_level_data['differential pressure value'].std()
    
    # Append mean and std values to the lists
    mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression to fit a line
slope, intercept, r_value, p_value, std_err = linregress(range(len(labels)), mean_values)

# Calculate R-squared
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars
plt.errorbar(labels, mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars')

# Plot the regression line
plt.plot(labels, [intercept + slope * i for i in range(len(labels))], color='r', label=f'Regression Line (R²={r_squared:.4f})')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Line (Set 5)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
print(f'Slope: {slope:.2f}')
print(f'Intercept: {intercept:.2f}')
print(f'R-squared: {r_squared:.4f}')

plt.show()
# Out:
# Slope: 4.67
# Intercept: 0.11
# R-squared: 0.9965

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define start and end time for each set of data
start_time_2 = pd.to_datetime('15:52:52')
end_time_2 = pd.to_datetime('16:12:00')

start_time_3 = pd.to_datetime('16:17:01')
end_time_3 = pd.to_datetime('16:34:44')

start_time_4 = pd.to_datetime('16:42:34')
end_time_4 = pd.to_datetime('17:04:53')

start_time_5 = pd.to_datetime('17:04:53')
end_time_5 = pd.to_datetime('17:22:10')

# Filter rows between start time and end time for each set of data
filtered_df_2 = df2.copy()
filtered_df_2 = filtered_df_2[(filtered_df_2['Timestamp'] >= start_time_2) & (filtered_df_2['Timestamp'] <= end_time_2)]

filtered_df_3 = df3.copy()
filtered_df_3 = filtered_df_3[(filtered_df_3['Timestamp'] >= start_time_3) & (filtered_df_3['Timestamp'] <= end_time_3)]

filtered_df_4 = df4.copy()
filtered_df_4 = filtered_df_4[(filtered_df_4['Timestamp'] >= start_time_4) & (filtered_df_4['Timestamp'] <= end_time_4)]

filtered_df_5 = df5.copy()
filtered_df_5 = filtered_df_5[(filtered_df_5['Timestamp'] >= start_time_5) & (filtered_df_5['Timestamp'] <= end_time_5)]

# Convert 'differential pressure value' to numeric, handling errors for each set of data
filtered_df_2.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df_2['differential pressure value'], errors='coerce')
filtered_df_3.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df_3['differential pressure value'], errors='coerce')
filtered_df_4.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df_4['differential pressure value'], errors='coerce')
filtered_df_5.loc[:, 'differential pressure value'] = pd.to_numeric(filtered_df_5['differential pressure value'], errors='coerce')

# Define the times to plot vertical lines at for each set of data
times_2= ["15:56:11", "15:57:11", #0
          "15:57:41", "15:58:41", #0.5
          "15:58:52", "15:59:52", #1
          "16:00:13", "16:01:13", #1.5
          "16:01:19", "16:02:19", #2
          "16:02:33", "16:03:33", #2.5
          "16:03:40", "16:04:40", #3 
          "16:04:52", "16:05:52", #3.5 
          "16:06:05", "16:07:05", #4 
          "16:07:20", "16:08:20", #4.5 
          "16:08:32", "16:09:32", #5 
          "16:09:42", "16:10:42", #5.5 
          "16:10:55", "16:11:55", #6 
];
times_3 = ["16:17:11", "16:18:11", "16:18:38", "16:19:38", "16:20:11", "16:21:11", "16:21:56", "16:22:56",
           "16:23:14", "16:24:14", "16:24:29", "16:25:29", "16:25:49", "16:26:49", "16:27:07", "16:28:07",
           "16:28:40", "16:29:14", "16:29:41", "16:30:41", "16:30:58", "16:31:58", "16:32:09", "16:33:09",
           "16:33:37", "16:34:37"]

times_4 = ["16:42:58", "16:43:58", "16:44:15", "16:45:15", "16:45:17", "16:46:17", "16:46:34", "16:47:34",
           "16:48:07", "16:49:07", "16:49:26", "16:50:26", "16:50:49", "16:51:49", "16:51:59", "16:52:59",
           "16:53:15", "16:54:15", "16:55:02", "16:56:02", "16:56:26", "16:57:26", "16:57:42", "16:58:42",
           "16:58:55", "16:59:55"]


times_5 = [
    "17:05:03", "17:06:03", # 0
    "17:06:33", "17:07:33", # 0.5
    "17:08:41", "17:09:41", # 1
    "17:09:53", "17:10:53", # 1.5
    "17:11:13", "17:11:14", # 2
    "17:12:15", "17:13:15", # 2.5
    "17:13:37", "17:14:37", # 3
    "17:14:51", "17:15:51", # 3.5
    "17:16:05", "17:17:05", # 4
    "17:17:16", "17:18:16", # 4.5
    "17:18:33", "17:19:33", # 5
    "17:19:47", "17:20:47", # 5.5
    "17:21:07", "17:22:07"  # 6
]


labels = ['0 cm H20', '0.5 cm H20', '1 cm H20', '1.5 cm H20', '2 cm H20', '2.5 cm H20', '3 cm H20', '3.5 cm H20',
          '4 cm H20', '4.5 cm H20', '5 cm H20', '5.5 cm H20', '6 cm H20']

# Convert the times to datetime for each set of data
times_2 = [pd.to_datetime(t) for t in times_2]
times_3 = [pd.to_datetime(t) for t in times_3]
times_4 = [pd.to_datetime(t) for t in times_4]
times_5 = [pd.to_datetime(t) for t in times_5]

# Initialize lists to store valid mean and std values for each pressure level for each set of data
mean_values_2 = []
std_values_2 = []

mean_values_3 = []
std_values_3 = []

mean_values_4 = []
std_values_4 = []

mean_values_5 = []
std_values_5 = []

# Loop through each pressure level for each set of data
for i in range(0, len(times_2)-1, 2):
    pressure_level_data_2 = filtered_df_2[(filtered_df_2['Timestamp'] >= times_2[i]) & (filtered_df_2['Timestamp'] <= times_2[i+1])]
    mean_value_2 = pressure_level_data_2['differential pressure value'].mean()
    std_value_2 = pressure_level_data_2['differential pressure value'].std()
    mean_values_2.append(mean_value_2)
    std_values_2.append(std_value_2)

for i in range(0, len(times_3)-1, 2):
    pressure_level_data_3 = filtered_df_3[(filtered_df_3['Timestamp'] >= times_3[i]) & (filtered_df_3['Timestamp'] <= times_3[i+1])]
    mean_value_3 = pressure_level_data_3['differential pressure value'].mean()
    std_value_3 = pressure_level_data_3['differential pressure value'].std()
    mean_values_3.append(mean_value_3)
    std_values_3.append(std_value_3)

for i in range(0, len(times_4)-1, 2):
    pressure_level_data_4 = filtered_df_4[(filtered_df_4['Timestamp'] >= times_4[i]) & (filtered_df_4['Timestamp'] <= times_4[i+1])]
    mean_value_4 = pressure_level_data_4['differential pressure value'].mean()
    std_value_4 = pressure_level_data_4['differential pressure value'].std()
    mean_values_4.append(mean_value_4)
    std_values_4.append(std_value_4)

for i in range(0, len(times_5)-1, 2):
    pressure_level_data_5 = filtered_df_5[(filtered_df_5['Timestamp'] >= times_5[i]) & (filtered_df_5['Timestamp'] <= times_5[i+1])]
    mean_value_5 = pressure_level_data_5['differential pressure value'].mean()
    std_value_5 = pressure_level_data_5['differential pressure value'].std()
    mean_values_5.append(mean_value_5)
    std_values_5.append(std_value_5)

# Perform linear regression for each set of data
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = linregress(range(len(mean_values_2)), mean_values_2)
r_squared_2 = r_value_2**2

slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = linregress(range(len(mean_values_3)), mean_values_3)
r_squared_3 = r_value_3**2

slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = linregress(range(len(mean_values_4)), mean_values_4)
r_squared_4 = r_value_4**2

slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = linregress(range(len(mean_values_5)), mean_values_5)
r_squared_5 = r_value_5**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars for each set of data
plt.errorbar(labels, mean_values_2, yerr=std_values_2, fmt='o', color='b', label='Mean with Error Bars (Set 2)')
plt.errorbar(labels, mean_values_3, yerr=std_values_3, fmt='o', color='g', label='Mean with Error Bars (Set 3)')
plt.errorbar(labels, mean_values_4, yerr=std_values_4, fmt='o', color='r', label='Mean with Error Bars (Set 4)')
plt.errorbar(labels, mean_values_5, yerr=std_values_5, fmt='o', color='m', label='Mean with Error Bars (Set 5)')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Lines (Sets 2, 3, 4, 5)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
plt.show()

# %%
# Initialize lists to store valid mean and std values for each pressure level for each set of data
mean_values = []
std_values = []

# Loop through each pressure level for each set of data
for i in range(0, min(len(times_2)-1, len(times_3)-1, len(times_4)-1, len(times_5)-1), 2):
    pressure_level_data_2 = filtered_df_2[(filtered_df_2['Timestamp'] >= times_2[i]) & (filtered_df_2['Timestamp'] <= times_2[i+1])]
    pressure_level_data_3 = filtered_df_3[(filtered_df_3['Timestamp'] >= times_3[i]) & (filtered_df_3['Timestamp'] <= times_3[i+1])]
    pressure_level_data_4 = filtered_df_4[(filtered_df_4['Timestamp'] >= times_4[i]) & (filtered_df_4['Timestamp'] <= times_4[i+1])]
    pressure_level_data_5 = filtered_df_5[(filtered_df_5['Timestamp'] >= times_5[i]) & (filtered_df_5['Timestamp'] <= times_5[i+1])]
    
    # Concatenate data for each set of pressure levels
    pressure_level_data = pd.concat([pressure_level_data_2, pressure_level_data_3, pressure_level_data_4, pressure_level_data_5])
            
    # Calculate mean and std
    mean_value = pressure_level_data['differential pressure value'].mean()
    std_value = pressure_level_data['differential pressure value'].std()
    
    mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression for each set of data
slope, intercept, r_value, p_value, std_err = linregress(range(len(mean_values_2)), mean_values_2)
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars for each set of data
plt.errorbar(labels, mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars (Sets 2-5)')

# Plot the regression line for each set of data
plt.plot(labels, [intercept + slope * i for i in range(len(labels))], color='b', label=f'Regression Line (R²={r_squared:.4f}) (Sets 2-5)')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Lines (Sets 2-5)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress

# Initialize lists to store valid mean and std values for each pressure level for each set of data
mean_values = []
std_values = []

# Loop through each pressure level for each set of data
for i in range(0, min(len(times_2)-1, len(times_3)-1, len(times_4)-1, len(times_5)-1), 2):
    pressure_level_data_2 = filtered_df_2[(filtered_df_2['Timestamp'] >= times_2[i]) & (filtered_df_2['Timestamp'] <= times_2[i+1])]
    pressure_level_data_3 = filtered_df_3[(filtered_df_3['Timestamp'] >= times_3[i]) & (filtered_df_3['Timestamp'] <= times_3[i+1])]
    pressure_level_data_4 = filtered_df_4[(filtered_df_4['Timestamp'] >= times_4[i]) & (filtered_df_4['Timestamp'] <= times_4[i+1])]
    pressure_level_data_5 = filtered_df_5[(filtered_df_5['Timestamp'] >= times_5[i]) & (filtered_df_5['Timestamp'] <= times_5[i+1])]
    
    # Concatenate data for each set of pressure levels
    pressure_level_data = pd.concat([pressure_level_data_2, pressure_level_data_3, pressure_level_data_4, pressure_level_data_5])
            
    # Calculate mean and std
    mean_value = pressure_level_data['differential pressure value'].mean()
    std_value = pressure_level_data['differential pressure value'].std()
    
    mean_values.append(mean_value)
    std_values.append(std_value)

# Perform linear regression for each set of data
slope, intercept, r_value, p_value, std_err = linregress(range(len(mean_values)), mean_values)
r_squared = r_value**2

# Create a new figure with a specific size (width, height)
plt.figure(figsize=(15, 6))

# Plot mean values with error bars for each set of data
plt.errorbar(labels, mean_values, yerr=std_values, fmt='o', color='b', label='Mean with Error Bars (Sets 2-5)')

# Plot the regression line for each set of data through the origin
plt.plot(labels, [slope * i for i in range(len(labels))], color='b', label=f'Regression Line (R²={r_squared:.4f}) (Sets 2-5)')

# Set the title and labels
plt.title('Mean and Error Bars for Each Pressure Level with Regression Lines (Sets 2-5)')
plt.xlabel('Pressure Level (cm H2O)')
plt.ylabel('Pressure Readings')

# Add a legend
plt.legend()

# Display the calculated values
plt.show()
