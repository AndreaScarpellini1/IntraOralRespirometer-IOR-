# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Read the text file
df = pd.read_csv('../AAB_DataCollection/DataCollection_1_22_2024/DataCollection1222024.txt')  # replace '\t' with your delimiter

# Save the DataFrame as a CSV file
df.to_csv('../AAB_DataCollection/DataCollection_1_22_2024/DataCollection1222024.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode              Data
# 0  15:16:03.427   RX  Pressure values:
# 1  15:16:03.427   RX             -0.09
# 2  15:16:03.546   RX  Pressure values:
# 3  15:16:03.548   RX             -0.19
# 4  15:16:03.666   RX  Pressure values:

# %%
# Now try selecting the 'Data' column
df = df.loc[df['Data'] != 'Pressure values:']
# Create a new column 'Sample' with values from 1 to the number of rows
df['Sample'] = range(1, len(df) + 1)

# Save the DataFrame as a CSV file
#df.to_csv('./AAB_DataCollection_1_22_2024/DataCollection1222024.csv', index=False)

df.head()  # prints the first 5 rows of the DataFrame
# Out:
#       Timestamp Mode   Data  Sample
# 1  15:16:03.427   RX  -0.09       1
# 3  15:16:03.548   RX  -0.19       2
# 5  15:16:03.667   RX  -0.09       3
# 7  15:16:03.787   RX  -0.19       4
# 9  15:16:03.907   RX   0.00       5

# %%
df.tail()
# Out:
#           Timestamp Mode   Data  Sample
# 50481  16:06:32.814   RX  -1.39   25241
# 50483  16:06:32.917   RX  -1.50   25242
# 50485  16:06:33.037   RX  -1.50   25243
# 50487  16:06:33.159   RX  -1.50   25244
# 50489  16:06:33.277   RX  -1.50   25245

# %%
# Convert 'Timestamp' to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('15:16:06').time()
end_time = pd.to_datetime('16:06:00').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Walking')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-10'), float('10'))

# Add a grid
plt.grid(True)
plt.savefig('Walking_1_22_2024.png')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('16:02:00').time()
end_time = pd.to_datetime('16:02:30').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Nose Respiration')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-10'), float('10'))

# Add a grid
plt.grid(True)
plt.savefig('Nose_1_22_2024.png')
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Define start and end time
start_time = pd.to_datetime('16:00:10').time()
end_time = pd.to_datetime('16:00:30').time()

# Filter rows between start time and end time
filtered_df = df.copy()
filtered_df = filtered_df[(filtered_df['Timestamp'].dt.time >= start_time) & (filtered_df['Timestamp'].dt.time <= end_time)]

filtered_df = filtered_df.copy()
# Now you can modify 'Data' without warnings
filtered_df.loc[:, 'Data'] = pd.to_numeric(filtered_df['Data'], errors='coerce')


# Create a new figure with a specific size (width, height)
plt.figure(figsize=(10, 6))

# Plot 'Data' against 'Timestamp'
plt.plot(filtered_df['Timestamp'], filtered_df['Data'])

# Set the title and labels
plt.title('Running')
plt.xlabel('Timestamp')
plt.ylabel('Data')

# Adjust the spacing of the labels
plt.xticks(rotation=45)

# Set the y-axis limits to cover the entire range
plt.ylim(float('-22'), float('20'))

# Add a grid
plt.grid(True)

plt.savefig('Running_1_22_2024.png')

# Show the plot
plt.show()
